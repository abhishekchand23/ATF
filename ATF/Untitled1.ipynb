# %%
install.packages('quantmod')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
install.packages("xtable")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
install.packages('boot')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
data=read.csv('cerExample.csv')

# %%
head(data)
# Out:
#   sbux   msft   sp500
# 1 2.7812 4.3750 408.14
# 2 3.3281 4.5469 424.21
# 3 3.1094 4.6562 414.03
# 4 3.7812 5.0312 417.80
# 5 3.6875 5.5469 418.68
# 6 4.7188 5.8203 431.35

# %%
sbux=data[,1]

# %%
mean(sbux)
# Out:
# [1] 16.11479

# %%
sbux_return=numeric(100)
for(i in (1:101)){
    if (i+1>101){
        break}
    else{
        sbux_return[i]=log(sbux[i+1])-log(sbux[i])
    }
    }

# %%
return22=function(x){
    log(tail(x,-1)/)
}
# Out:
#   [1]  0.179519081 -0.067971789  0.195611638 -0.025092698  0.246605808
#   [6] -0.020078159  0.039740329 -0.060229895  0.047157813  0.019554919
#  [11]  0.214059933  0.020619287 -0.031090587  0.020834087  0.121220877
#  [16] -0.023103021 -0.184192465  0.000000000  0.075711822 -0.031748698
#  [21]  0.047261090  0.199262910 -0.042925045 -0.121077932  0.138469674
#  [26] -0.026202372 -0.202889872  0.162244853 -0.011583971  0.025321538
#  [31] -0.136132174 -0.005213567  0.005213567 -0.021053409  0.212444821
#  [36]  0.203596782  0.047965358  0.067872071 -0.054582910  0.035654900
#  [41]  0.073652910 -0.005934736 -0.226124179  0.050920090  0.279667059
#  [46]  0.151470404  0.000000000  0.040637646 -0.082996920  0.230806424
#  [51]  0.007604599 -0.015267472  0.063335875 -0.190295503  0.179406103
#  [56] -0.018416727 -0.126651238  0.008403411  0.052965536  0.211972819
#  [61]  0.050088591  0.001523111  0.019620880 -0.236685385  0.055262679
# ...

# %%
plot.ts(sbux_return)
# Out:
# plot without title

# %%
obs=100
for (i in (1:2000)){
    aa=sample(sbux_return,obs,replace=T)
    mean_sbux[i]=mean(aa)
}

# %%
hist(mean_sbux)
# Out:
# Plot with title “Histogram of mean_sbux”
